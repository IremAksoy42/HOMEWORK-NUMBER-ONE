# %%
from __future__ import print_function, division

import nsfg

# %%
pres = nsfg.ReadFemPreg()

pres
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 9           7         2        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# ...

# %%
columnslist=pres.columns
columnslist
# Out:
# Index([         u'caseid',        u'pregordr',       u'howpreg_n',
#              u'howpreg_p',        u'moscurrp',        u'nowprgdk',
#               u'pregend1',        u'pregend2',        u'nbrnaliv',
#               u'multbrth',
#        ...
#             u'laborfor_i',      u'religion_i',         u'metro_i',
#                u'basewgt', u'adj_mod_basewgt',        u'finalwgt',
#                 u'secu_p',            u'sest',         u'cmintvw',
#            u'totalwgt_lb'],
#       dtype='object', length=244)

# %%
pres.head(20)
pres.tail(30)
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 13563   12547         2        NaN        NaN       NaN       NaN       6.0
# 13564   12547         3        NaN        NaN       NaN       NaN       6.0
# 13565   12550         1        NaN        NaN       NaN       NaN       6.0
# 13566   12551         1        NaN        NaN       NaN       NaN       5.0
# 13567   12554         1        NaN        NaN       NaN       NaN       3.0
# 13568   12554         2        NaN        NaN       NaN       NaN       4.0
# 13569   12556         1        NaN        NaN       NaN       NaN       6.0
# 13570   12556         2        NaN        NaN       NaN       NaN       6.0
# 13571   12556         3        NaN        NaN       NaN       NaN       6.0
# 13572   12556         4        NaN        NaN       NaN       NaN       6.0
# 13573   12561         1        NaN        NaN       NaN       NaN       6.0
# ...

# %%
print ( "There are ", len(pres.head(20))+len(pres.tail(30)), " rows and " , len(columnslist)," columns")
# Out:
# There are  50  rows and  244  columns

# %%
pres["agescrn"]
# Out:
# 0        44
# 1        44
# 2        20
# 3        20
# 4        20
# 5        40
# 6        40
# 7        40
# 8        39
# 9        39
# 10       40
# 11       36
# 12       36
# 13       36
# 14       32
# 15       32
# 16       32
# 17       42
# 18       42
# 19       35
# 20       35
# 21       42
# 22       42
# 23       35
# 24       35
# 25       35
# 26       39
# 27       44
# 28       44
# 29       44
#          ..
# 13563    32
# 13564    32
# 13565    20
# 13566    38
# 13567    32
# 13568    32
# 13569    42
# 13570    42
# 13571    42
# 13572    42
# 13573    44
# 13574    44
# 13575    33
# 13576    34
# 13577    34
# 13578    27
# 13579    27
# 13580    35
# 13581    35
# 13582    35
# 13583    31
# 13584    31
# 13585    37
# 13586    37
# 13587    37
# 13588    37
# 13589    37
# 13590    37
# 13591    37
# 13592    37
# Name: agescrn, dtype: int64

# %%
pres.agescrn.min()
# Out:
# 15

# %%
pres.agescrn.max()
# Out:
# 44

# %%
pres["prglngth"] = pres.caseid==2298
pres["prglngth"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 13563    False
# 13564    False
# 13565    False
# 13566    False
# 13567    False
# 13568    False
# 13569    False
# 13570    False
# 13571    False
# 13572    False
# 13573    False
# 13574    False
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# 13580    False
# 13581    False
# 13582    False
# 13583    False
# 13584    False
# 13585    False
# 13586    False
# 13587    False
# 13588    False
# 13589    False
# ...

# %%
preg.row

preg[preg.caseid==2298]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-15d25eefabb2> in <module>()
# ----> 1 preg.row
#       2
#       3 preg[preg.caseid==2298]
#
# C:\Users\iremaksoy\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
pres.outcome.value_counts()
# Out:
# 1    9148
# 4    1921
# 2    1862
# 6     352
# 5     190
# 3     120
# Name: outcome, dtype: int64

# %%
preg.average = preg.numpregs / 2.0
preg.average
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-332eef903d9f> in <module>()
# ----> 1 preg.average = preg.numpregs / 2.0
#       2 preg.average
#
# C:\Users\iremaksoy\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'numpregs'

# %%
preg.outcome.value_counts().sort_index()
# Out:
# 4445

# %%
preg.birthwgt_lb.value_counts().sort_index()
# Out:
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# 15.0       1
# Name: birthwgt_lb, dtype: int64

# %%
preg.birthord.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13        True
# 14        True
# 15       False
# 16       False
# 17       False
# 18        True
# 19       False
# 20       False
# 21       False
# 22        True
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 13563    False
# 13564    False
# 13565    False
# 13566    False
# 13567     True
# 13568     True
# 13569    False
# 13570    False
# 13571    False
# 13572    False
# 13573    False
# 13574    False
# 13575     True
# 13576    False
# 13577     True
# 13578    False
# 13579    False
# 13580     True
# 13581    False
# 13582     True
# 13583     True
# 13584    False
# 13585     True
# 13586     True
# 13587     True
# 13588    False
# 13589     True
# ...

# %%
preg.birthord.isnull().value_counts()
# Out:
# False    9148
# True     4445
# Name: birthord, dtype: int64

# %%
preg.birthord.isnull().sum()
# Out:
# 4445
